# %% [markdown]
# # Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# **Філіал С найприбутковіший**

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby('City').agg({'gross income': 'sum', 'Total': 'mean', 'Invoice ID': 'count', 'Unit price':'mean'})
# Out:
#            gross income       Total  Invoice ID  Unit price
# City
# Mandalay      5057.0320  319.872506         332   55.659277
# Naypyitaw     5265.1765  337.099715         328   56.609024
# Yangon        5057.1605  312.354031         340   54.780853

# %% [markdown]
# **У місті Naypyitaw знаходиться філіал з найвищим прибутком. У цьому місті також зафіксовано найвищу середню ціну товару та найменшу кількість покупок, що призводить до високого середнього чеку.**

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index='Branch', columns='Product line', values='Invoice ID', aggfunc='count')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category.sort_values(by='Electronic accessories', ascending=False)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# З даних попереднього аналізу ми бачимо що найбільші прибутки є в місті Naypyitaw.
# 1. У місті Naypyitaw (як і загалом) найбільший дохід приносить лінійка товарів Food and beverages. У інших містах дохід від цієї групи значно нижчий. Рекомендується провести детальний аналіз асортименту цієї групи в різних містах.
# 2. Найбільше покупців у всій мережі та в Naypyitaw використовує готівкову оплату, тоді як електронним гаманцем переважно розраховуються у Yangon. Рекомендується проаналізувати витрати на різні способи оплати, щоб визначити найменш затратний для організації.
# 3. Загалом більше покупок здійснюють жінки, особливо у групі Food and beverages, тоді як чоловіки переважають у групі Health and beauty. За містами: у Naypyitaw більше покупців — жінки, а у Mandalay — чоловіки. Рекомендується звернутися до додаткових джерел, щоб проаналізувати демографічні дані населення цих міст.

# %%
pd.pivot_table(df, index='Product line', columns='City', values='gross income', aggfunc='sum').sort_values(by='Naypyitaw', ascending=False)
# Out:
# City                    Mandalay  Naypyitaw     Yangon
# Product line
# Food and beverages      724.5185  1131.7550   817.2905
# Fashion accessories     781.5865  1026.6700   777.7385
# Electronic accessories  811.9735   903.2845   872.2435
# Health and beauty       951.4600   791.2060   599.8930
# Sports and travel       951.8190   750.5680   922.5095
# Home and lifestyle      835.6745   661.6930  1067.4855

# %%
df.groupby('Product line')['gross income'].sum().sort_values(ascending=False)
# Out:
# Product line
# Food and beverages        2673.5640
# Sports and travel         2624.8965
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Home and lifestyle        2564.8530
# Health and beauty         2342.5590
# Name: gross income, dtype: float64

# %%
df.groupby('Payment').agg({'gross income': 'sum', 'Invoice ID': 'count'}).sort_values(by='gross income', ascending=False)
# Out:
#              gross income  Invoice ID
# Payment
# Cash             5343.170         344
# Ewallet          5237.767         345
# Credit card      4798.432         311

# %%
pd.pivot_table(df, index=['City'], columns='Payment', values='gross income', aggfunc='sum').sort_values(by='Cash', ascending=False)
# Out:
# Payment         Cash  Credit card   Ewallet
# City
# Naypyitaw  2051.7075    1444.1650  1769.304
# Mandalay   1682.8315    1778.3265  1595.874
# Yangon     1608.6310    1575.9405  1872.589

# %%
df.groupby('Gender')['gross income'].sum().sort_values(ascending=False)
# Out:
# Gender
# Female    7994.425
# Male      7384.944
# Name: gross income, dtype: float64

# %%
pd.pivot_table(df, index=['Product line'], columns='Gender', values='gross income', aggfunc='sum').sort_values(by='Female', ascending=False)
# Out:
# Gender                     Female       Male
# Product line
# Food and beverages      1579.5675  1093.9965
# Fashion accessories     1449.4000  1136.5950
# Home and lifestyle      1430.3275  1134.5255
# Sports and travel       1360.7010  1264.1955
# Electronic accessories  1290.5725  1296.9290
# Health and beauty        883.8565  1458.7025

# %%
pd.pivot_table(df, index=['City'], columns='Gender', values='gross income', aggfunc='sum').sort_values(by='Female', ascending=False)
# Out:
# Gender       Female       Male
# City
# Naypyitaw  2937.403  2327.7735
# Yangon     2536.627  2520.5335
# Mandalay   2520.395  2536.6370
