# %% [markdown]
# # Домашнє завдання №1

# %% [markdown]
# # Завдання 1.
# Ви —  продакт менеджер в компанії, яка займається мобільними додатками.
# Ваша модель монетизації — підписка. У травні 2019 року до вас приєдналося 100 підписників, у червні — 150, у липні — 170.
# Скільки ці користувачі принесли вам до початку травня 2021 року (за два роки),
# якщо щомісячний рівень відтоку становить 5%, а підписка коштує $10?
#
# **Дано:**
#
# Початкова кількість (з липня) S1 - 170
#
# Коефіцієнт q - 0,95
#
# Кількість місяців (з липня 2019 до квітня 2021) n - 22
#
# Ціна - 10$
#
#
# 1. **Визначаємо кількість підписників за 22 місяці з липня 2019 до квітня 2021:**
#
# Сума геометричної прогресії: Sn = S1*(1-q^n)/(1-q)
#
# S22 = 170 * (1 - 0,95 ^ 22) / (1 - 0,95) = 2300 підписників за 22 місяці
#
#
# 2. **Загальна кількість підписників за два роки буде становити:**
#
# 2300 + 100 + 150 = 2550
#
#
# 3. **Дохід за два роки становитиме:**
#
# Сума = Кількість підписників * Ціну
#
# 2550 * 10 = **25500$**

# %%
S1 = 170
q = 0.95
n = 22

Sn = S1 * (1 - q**n) / (1 - q)

print (Sn)
print (round(Sn))
# Out:
# 2299.985947089387
# 2300

# %%
S24=2300+100+150
print (S24)
# Out:
# 2550

# %% [markdown]
# # Завдання 2.
#    Ви — менеджер по роботі з продуктом в компанії, яка розробляє мобільні ігри.
# У січні 2020 року у вас було 2000 активних користувачів.
# Щомісяця кількість нових користувачів зростає на 3%, але водночас 2% існуючих користувачів перестають користуватися додатком.
# У результаті, ефективне зростання активних користувачів складає 1% щомісяця.
# Ваша мета — визначити кумулятивну кількість активних користувачів за весь період
# від січня 2020 року до кінця грудня 2021 року (тобто за 24 місяці), враховуючи щомісячний приріст 1%.
# Питання: Якою буде загальна кількість активних користувачів, накопичена за 24 місяці?
#
# **Дано:**
#
# S1 - 2000
#
# q - 1.01
#
# n - 24
#
# **Загальна кількість куористувачів за 24 місяці буде 53947**
#
# Sn = S1 * (q^n - 1) / (q - 1) = 2000 * (1.01^24 - 1) / (1.01 - 1) = 53947

# %%
S1 = 2000
q = 1.01
n = 24

Sn = S1 * (q**n - 1) / (q - 1)

print (Sn)
print (round(Sn))
# Out:
# 53946.9297063829
# 53947

# %% [markdown]
# # Завдання 3.
# Ви — менеджер з розвитку бізнесу в компанії, що займається створенням платформи для онлайн-курсів.
# У січні 2021 року ви залучили 500 нових користувачів. У лютому кількість нових користувачів зросла на 50%,
# у березні — ще на 20%. З квітня приріст нових користувачів стабілізувався на рівні 10% щомісяця.
# Скільки користувачів ми залучили загалом за перше півріччя 2021 року?
#
# **Дано:**
#
# S1 = 500
#
# S2 = +50% = 500 * 1,5 = 750
#
# S3 = +20% = 750 * 1,2 = 900
#
# n = 4
#
# q = 1.1
#
# Sn = S3 * (q**n - 1) / (q - 1) = 900 * (1.1^3 - 1) / (1.1 - 1) = 4177
#
# **За перше півріччя залучили 5427**
#
# 6 місяців = січень (500) + лютий (750) + березень-червень (4177)

# %%
S3 = 900
q = 1.1
n = 4

Sn = S3 * (q**n - 1) / (q - 1)

print (Sn)
print (round(Sn))
# Out:
# 4176.9
# 4177

# %%
S6 = 500 + 750 + 4177
print (S6)
# Out:
# 5427
